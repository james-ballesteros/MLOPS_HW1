# %%
import requests

url = "http://127.0.0.1:8000/predict"

data = {
    "data": [
        [0.456, 0.939, 2.065, 0.226, 0.421, -0.012, 0.718, 0.404, 0.587, 0.594, 0.078, 0.178, 0.176, 2.078],
        [0.470, 0.940, 2.298, 0.241, 0.435, -0.011, 0.784, 0.427, 0.619, 0.621, 0.083, 0.182, 0.189, 2.472],
    ]
}

response = requests.post(url, json=data)
print(response.json())
